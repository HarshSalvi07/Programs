# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Harsh suhas
# [nltk_data]     salvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Harsh suhas
# [nltk_data]     salvi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
corpus = """Hello my name is Harsh. 
I am 18 years old and I have many ambitions."""

print(corpus)
sent_tokenize(corpus)
# Out:
# Hello my name is Harsh.
# I am 18 years old and I have many ambitions.
# ['Hello my name is Harsh.', 'I am 18 years old and I have many ambitions.']
